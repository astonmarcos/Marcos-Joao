# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
ipca = pd.read_csv('ipca.csv', sep = ',',decimal = '.')
desemprego = pd.read_csv('taxadesemprego.csv', sep = ',',decimal = '.')

# %%
ipca.head()
# Out:
#       periodo  IPCA
# 0  15-03-2020  0.07
# 1  15-04-2020 -0.31
# 2  15-05-2020 -0.38
# 3  15-06-2020  0.26
# 4  15-07-2020  0.36

# %%
desemprego.head()
# Out:
#    taxa_De_desemprego
# 0                12.2
# 1                12.6
# 2                12.9
# 3                13.3
# 4                13.8

# %%
ipca.dtypes
# Out:
# periodo     object
# IPCA       float64
# dtype: object

# %%
ipca.ipca = ipca.IPCA.astype(float)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
desemprego.dtypes
# Out:
# taxa_De_desemprego    float64
# dtype: object

# %%
ipca.periodo = pd.to_datetime(ipca.periodo, format='%d-%m-%Y')

# %%
desemprego.desemprego = desemprego.taxa_De_desemprego.astype(float)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
ipca.dtypes
# Out:
# periodo    datetime64[ns]
# IPCA              float64
# dtype: object

# %%
desemprego.dtypes
# Out:
# taxa_De_desemprego    float64
# dtype: object

# %%
plt.rcParams['figure.figsize'] = (10,6)
plt.title('IPCA x taxa de desemprego em % em 2020-21',fontsize = 16)
plt.plot(ipca.periodo,ipca.IPCA,lw =3, label = 'ipca', c = 'purple', linestyle = 'solid')
plt.plot(ipca.periodo,desemprego.desemprego,lw =3, label = 'desemprego', c = 'orange', linestyle = 'solid')
ax = plt.gca()
ax.set_facecolor('lightgrey')
plt.xlabel('Período',fontsize = 15)
plt.ylabel("Taxas em %",fontsize = 15)
plt.xticks(rotation=30)
plt.legend(loc = 'upper right')
